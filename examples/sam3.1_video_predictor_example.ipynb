# %%
# Copyright (c) Meta Platforms, Inc. and affiliates.

# %% [markdown]
# ## Video segmentation and tracking with SAM 3.1 (Object Multiplex)
#
# This notebook demonstrates how to use SAM 3.1 with Object Multiplex for interactive video segmentation and dense tracking. Object Multiplex groups objects into fixed-capacity buckets and processes them jointly, drastically reducing redundant computation compared to SAM 3's per-object inference. It covers the following capabilities:
#
# - **Text prompts**: Using natural language descriptions to segment objects (e.g., "person", "shoe")
# - **Point prompts**: Adding positive/negative clicks to segment and refine objects
#
# We use the terms _segment_ or _mask_ to refer to the model prediction for an object on a single frame, and _masklet_ to refer to the spatio-temporal masks across the entire video.

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/facebookresearch/sam3/blob/main/notebooks/sam3.1_video_predictor_example.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
using_colab = False

# %%
if using_colab:
    import torch
    import torchvision
    print("PyTorch version:", torch.__version__)
    print("Torchvision version:", torchvision.__version__)
    print("CUDA is available:", torch.cuda.is_available())
    import sys
    # !{sys.executable} -m pip install opencv-python matplotlib scikit-learn
    # !{sys.executable} -m pip install 'git+https://github.com/facebookresearch/sam3.git'

# %%
# !nvidia-smi
# Out:
# Fri May 22 13:11:32 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.159.03             Driver Version: 580.159.03     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4090        On  |   00000000:21:00.0 Off |                  Off |
# |  0%   33C    P8             17W /  450W |    6874MiB /  24564MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A         1758015      C   ...acobone/sam3/myenv/bin/python       6864MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## Set-up

# %%
import os
import sam3
import torch

sam3_root = os.path.join(os.path.dirname(sam3.__file__), "..")
# Out:
# /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)

# %% [markdown]
# #### Inference and visualization utils

# %%
from sam3.model_builder import build_sam3_multiplex_video_predictor

predictor = build_sam3_multiplex_video_predictor()
# Out:
# dynamic_multimask_via_stability is reset to False in the multiplex model
# INFO 2026-05-22 13:12:23,928 2250004 sam3_multiplex_base.py: 336: `setting max_num_objects` to 16 -- creating num_obj_for_compile=1 objects for torch.compile cache
# Missing keys (64): ['detector.backbone.vision_backbone.trunk.blocks.0.attn.freqs_cis_real', 'detector.backbone.vision_backbone.trunk.blocks.0.attn.freqs_cis_imag', 'detector.backbone.vision_backbone.trunk.blocks.1.attn.freqs_cis_real', 'detector.backbone.vision_backbone.trunk.blocks.1.attn.freqs_cis_imag', 'detector.backbone.vision_backbone.trunk.blocks.2.attn.freqs_cis_real', 'detector.backbone.vision_backbone.trunk.blocks.2.attn.freqs_cis_imag', 'detector.backbone.vision_backbone.trunk.blocks.3.attn.freqs_cis_real', 'detector.backbone.vision_backbone.trunk.blocks.3.attn.freqs_cis_imag', 'detector.backbone.vision_backbone.trunk.blocks.4.attn.freqs_cis_real', 'detector.backbone.vision_backbone.trunk.blocks.4.attn.freqs_cis_imag']...

# %%
import glob
import os

import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from sam3.visualization_utils import (
    load_frame,
    prepare_masks_for_visualization,
    visualize_formatted_frame_output,
)

plt.rcParams["axes.titlesize"] = 12
plt.rcParams["figure.titlesize"] = 12


def propagate_in_video(predictor, session_id):
    outputs_per_frame = {}
    for response in predictor.handle_stream_request(
        request=dict(
            type="propagate_in_video",
            session_id=session_id,
        )
    ):
        outputs_per_frame[response["frame_index"]] = response["outputs"]

    return outputs_per_frame


def abs_to_rel_coords(coords, IMG_WIDTH, IMG_HEIGHT, coord_type="point"):
    """Convert absolute coordinates to relative coordinates (0-1 range)

    Args:
        coords: List of coordinates
        coord_type: 'point' for [x, y] or 'box' for [x, y, w, h]
    """
    if coord_type == "point":
        return [[x / IMG_WIDTH, y / IMG_HEIGHT] for x, y in coords]
    elif coord_type == "box":
        return [
            [x / IMG_WIDTH, y / IMG_HEIGHT, w / IMG_WIDTH, h / IMG_HEIGHT]
            for x, y, w, h in coords
        ]
    else:
        raise ValueError(f"Unknown coord_type: {coord_type}")

# %% [markdown]
# ### Loading an example video
#
# We assume that the video is stored as either **a list of JPEG frames with filenames like `<frame_index>.jpg`** or **an MP4 video**.
#
# Note that you can extract their JPEG frames using ffmpeg (https://ffmpeg.org/) as follows:
# ```
# ffmpeg -i <your_video>.mp4 -q:v 2 -start_number 0 <output_dir>/'%05d.jpg'
# ```
# where `-q:v` generates high-quality JPEG frames and `-start_number 0` asks ffmpeg to start the JPEG file from `00000.jpg`.

# %%
# "video_path" needs to be either a JPEG folder or a MP4 video file
video_path = f"{sam3_root}/assets/videos/0001"

# %%
# load "video_frames_for_vis" for visualization purposes (they are not used by the model)
if isinstance(video_path, str) and video_path.endswith(".mp4"):
    cap = cv2.VideoCapture(video_path)
    video_frames_for_vis = []
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        video_frames_for_vis.append(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    cap.release()
else:
    video_frames_for_vis = glob.glob(os.path.join(video_path, "*.jpg"))
    try:
        video_frames_for_vis.sort(
            key=lambda p: int(os.path.splitext(os.path.basename(p))[0])
        )
    except ValueError:
        print(
            f'frame names are not in "<frame_index>.jpg" format: {video_frames_for_vis[:5]=}, '
            f"falling back to lexicographic sort."
        )
        video_frames_for_vis.sort()

# %% [markdown]
# ### Opening an inference session on this video
#
# SAM 3.1 requires stateful inference for interactive video segmentation, so we need to initialize an **inference session** on this video.
#
# During initialization, it loads all the video frames and stores their pixels in the session state.

# %%
response = predictor.handle_request(
    request=dict(
        type="start_session",
        resource_path=video_path,
    )
)
session_id = response["session_id"]
# Out:
# frame loading (image folder) [rank=0]:   1%|▏         | 4/270 [00:00<00:17, 15.43it/s]INFO 2026-05-22 13:12:43,606 2250004 sam3_base_predictor.py: 153: started new session ae4a1c75-35f4-4d85-a003-2525b85006bf

# %% [markdown]
# ### Video promptable concept segmentation with text
#
# Using SAM 3.1 you can describe objects using natural language, and the model will automatically detect and track all instances of that object throughout the video.
#
# In the example below, we add a text prompt on frame 0 and propagation throughout the video. Here we use the text prompt "person" to detect all people in the video. SAM 3.1 will automatically identify multiple person instances and assign each a unique object ID.
#
# Note that the first call might be slower due to setting up buffers. **You can rerun all the cells below when measuring speed.**

# %%
# note: in case you already ran one text prompt and now want to switch to another text prompt
# it's required to reset the session first (otherwise the results would be wrong)
_ = predictor.handle_request(
    request=dict(
        type="reset_session",
        session_id=session_id,
    )
)

# %%
prompt_text_str = "person"
frame_idx = 0  # add a text prompt on frame 0
response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        text=prompt_text_str,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3.1 Dense Tracking outputs"],
    figsize=(6, 4),
)
# Out:
# INFO 2026-05-22 13:12:43,697 2250004 sam3_multiplex_tracking.py:1677: Running add_prompt on frame 0
# frame loading (image folder) [rank=0]:  66%|██████▌   | 177/270 [00:07<00:12,  7.71it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 3
#       1 prompt_text_str = "person"
#       2 frame_idx = 0  # add a text prompt on frame 0
# ----> 3 response = predictor.handle_request(
#       4     request=dict(
#       5         type="add_prompt",
#       6         session_id=session_id,
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File /cluster/scratch/niacobone/sam3/sam3/model/sam3_base_predictor.py:61, in Sam3BasePredictor.handle_request(self, request)
#      54     return self.start_session(
#      55         resource_path=request["resource_path"],
#      56         session_id=request.get("session_id", None),
#      57         offload_video_to_cpu=request.get("offload_video_to_cpu", False),
#      58         offload_state_to_cpu=request.get("offload_state_to_cpu", False),
#      59     )
#      60 elif request_type == "add_prompt":
# ---> 61     return self.add_prompt(
#      62         session_id=request["session_id"],
#      63         frame_idx=request["frame_index"],
#      64         text=request.get("text", None),
#      65         points=request.get("points", None),
#      66         point_labels=request.get("point_labels", None),
#      67         clear_old_points=request.get("clear_old_points", True),
#      68         bounding_boxes=request.get("bounding_boxes", None),
#      69         bounding_box_labels=request.get("bounding_box_labels", None),
#      70         clear_old_boxes=request.get("clear_old_boxes", True),
#      71         output_prob_thresh=request.get(
#      72             "output_prob_thresh",
#      73             getattr(self, "default_output_prob_thresh", 0.5),
#      74         ),
#      75         obj_id=request.get("obj_id", None),
#      76         rel_coordinates=request.get("rel_coordinates", True),
#      77     )
#      78 elif request_type == "remove_object":
#      79     return self.remove_object(
#      80         session_id=request["session_id"],
#      81         frame_idx=request.get("frame_index", 0),
#      82         obj_id=request["obj_id"],
#      83     )
#
# File /cluster/scratch/niacobone/sam3/sam3/model/sam3_base_predictor.py:213, in Sam3BasePredictor.add_prompt(self, session_id, frame_idx, text, points, point_labels, clear_old_points, bounding_boxes, bounding_box_labels, clear_old_boxes, output_prob_thresh, obj_id, rel_coordinates)
#     210 filtered_kwargs = {k: v for k, v in kwargs.items() if k in valid_params}
#     212 with torch.autocast(device_type="cuda", dtype=torch.bfloat16):
# --> 213     frame_idx, outputs = self.model.add_prompt(**filtered_kwargs)
#     214 return {"frame_index": frame_idx, "outputs": outputs}
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File /cluster/scratch/niacobone/sam3/sam3/model/sam3_multiplex_tracking.py:2724, in Sam3MultiplexTrackingWithInteractivity.add_prompt(self, inference_state, frame_idx, text_str, clear_old_points, points, point_labels, boxes_xywh, box_labels, clear_old_boxes, output_prob_thresh, obj_id, rel_coordinates)
#    2722 self.use_batched_grounding = False
#    2723 try:
# -> 2724     return super().add_prompt(
#    2725         inference_state,
#    2726         frame_idx,
#    2727         text_str=text_str,
#    2728         clear_old_points=clear_old_points,
#    2729         points=points,
#    2730         point_labels=point_labels,
#    2731         boxes_xywh=boxes_xywh,
#    2732         box_labels=box_labels,
#    2733         clear_old_boxes=clear_old_boxes,
#    2734         output_prob_thresh=output_prob_thresh,
#    2735     )
#    2736 finally:
#    2737     self.use_batched_grounding = _orig_batched
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File /cluster/scratch/niacobone/sam3/sam3/model/sam3_multiplex_tracking.py:1732, in Sam3MultiplexTracking.add_prompt(self, inference_state, frame_idx, text_str, clear_old_points, points, point_labels, boxes_xywh, box_labels, clear_old_boxes, output_prob_thresh)
#    1730 with torch.profiler.record_function("add_prompt._init_backbone_out"):
#    1731     inference_state["backbone_out"] = self._init_backbone_out(inference_state)
# -> 1732 out = self._run_single_frame_inference(
#    1733     inference_state,
#    1734     frame_idx,
#    1735     reverse=False,
#    1736 )
#    1737 return frame_idx, self._postprocess_output(inference_state, out)
#
# File /cluster/scratch/niacobone/sam3/sam3/model/sam3_multiplex_tracking.py:620, in Sam3MultiplexTracking._run_single_frame_inference(self, inference_state, frame_idx, reverse, is_instance_processing)
#     604 inference_state["feature_cache"]["text"] = {
#     605     text_batch_key: {
#     606         "language_features": inference_state["backbone_out"][
#    (...)    610     }
#     611 }
#     612 # run inference for the current frame
#     613 (
#     614     obj_id_to_mask,
#     615     obj_id_to_score,
#     616     tracker_states_local_new,
#     617     tracker_metadata_new,
#     618     frame_stats,
#     619     _,
# --> 620 ) = self._det_track_one_frame(
#     621     frame_idx=frame_idx,
#     622     num_frames=inference_state["num_frames"],
#     623     reverse=reverse,
#     624     input_batch=input_batch,
#     625     geometric_prompt=geometric_prompt,
#     626     tracker_states_local=tracker_states_local,
#     627     tracker_metadata_prev=inference_state["tracker_metadata"],
#     628     feature_cache=inference_state["feature_cache"],
#     629     orig_vid_height=inference_state["orig_height"],
#     630     orig_vid_width=inference_state["orig_width"],
#     631     is_image_only=inference_state["is_image_only"],
#     632 )
#     633 # update inference state
#     634 inference_state["sam2_inference_states"] = tracker_states_local_new
#
# File /cluster/scratch/niacobone/sam3/sam3/model/sam3_multiplex_base.py:447, in Sam3MultiplexBase._det_track_one_frame(self, frame_idx, num_frames, reverse, input_batch, geometric_prompt, tracker_states_local, tracker_metadata_prev, feature_cache, orig_vid_height, orig_vid_width, is_image_only)
#     444 profiling_enabled = self._start_profiling(frame_idx)
#     446 try:
# --> 447     return self._det_track_one_frame_impl(
#     448         frame_idx=frame_idx,
#     449         num_frames=num_frames,
#     450         reverse=reverse,
#     451         input_batch=input_batch,
#     452         geometric_prompt=geometric_prompt,
#     453         tracker_states_local=tracker_states_local,
#     454         tracker_metadata_prev=tracker_metadata_prev,
#     455         feature_cache=feature_cache,
#     456         orig_vid_height=orig_vid_height,
#     457         orig_vid_width=orig_vid_width,
#     458         is_image_only=is_image_only,
#     459     )
#     460 finally:
#     461     if profiling_enabled:
#
# File /cluster/scratch/niacobone/sam3/sam3/model/sam3_multiplex_base.py:506, in Sam3MultiplexBase._det_track_one_frame_impl(self, frame_idx, num_frames, reverse, input_batch, geometric_prompt, tracker_states_local, tracker_metadata_prev, feature_cache, orig_vid_height, orig_vid_width, is_image_only)
#     500 # Step 1: run backbone and FA in a distributed manner -- this is done via Sam3MultiplexDetector,
#     501 # a distributed FA model (assigned to `self.detector`) that shards frames in a round-robin manner.
#     502 # It returns a "det_out" dict for `frame_idx` and fills SAM2 backbone features for `frame_idx`
#     503 # into `feature_cache`. Despite its distributed inference under the hood, the results would be
#     504 # the same as if it is running backbone and FA for every frame on a single GPU.
#     505 with torch.profiler.record_function("run_backbone_and_detection"):
# --> 506     det_out, pos_pred_mask = self.run_backbone_and_detection(
#     507         frame_idx=frame_idx,
#     508         num_frames=num_frames,
#     509         reverse=reverse,
#     510         input_batch=input_batch,
#     511         geometric_prompt=geometric_prompt,
#     512         feature_cache=feature_cache,
#     513         use_batched_grounding=self.use_batched_grounding,
#     514         batched_grounding_batch_size=self.batched_grounding_batch_size,
#     515     )
#     517 # Step 2: each GPU propagates its local SAM2 states to get the SAM2 prediction masks.
#     518 # the returned `tracker_low_res_masks_global` contains the concatenated masklet predictions
#     519 # gathered from all GPUs (as if they are propagated on a single GPU). Note that this step only
#     520 # runs the SAM2 propagation step, but doesn't encode new memory for the predicted masks;
#     521 # we defer memory encoding to `run_tracker_update_execution_phase` after resolving all heuristics.
#     522 with torch.profiler.record_function("run_tracker_propagation"):
#
# File /cluster/scratch/niacobone/sam3/sam3/model/sam3_multiplex_base.py:707, in Sam3MultiplexBase.run_backbone_and_detection(self, frame_idx, num_frames, input_batch, geometric_prompt, feature_cache, reverse, use_batched_grounding, batched_grounding_batch_size)
#     704         feature_cache["multigpu_buffer"] = {}
#     706     with torch.profiler.record_function("forward_video_grounding_multigpu"):
# --> 707         sam3_image_out, _ = self.detector.forward_video_grounding_multigpu(
#     708             backbone_out=backbone_out,
#     709             find_inputs=input_batch.find_inputs,
#     710             geometric_prompt=geometric_prompt,
#     711             frame_idx=frame_idx,
#     712             num_frames=num_frames,
#     713             multigpu_buffer=feature_cache["multigpu_buffer"],
#     714             track_in_reverse=reverse,
#     715             # also get the SAM2 backbone features
#     716             return_sam2_backbone_feats=True,
#     717             # run NMS as a part of distributed FA computation
#     718             run_nms=self.det_nms_thresh > 0.0,
#     719             nms_prob_thresh=self.score_threshold_detection,
#     720             nms_iou_thresh=self.det_nms_thresh,
#     721             nms_use_iom=self.det_nms_use_iom,
#     722             # pass max_frame_num_to_track to respect tracking limits
#     723             max_frame_num_to_track=max_frame_num_to_track,
#     724             propagate_in_video_start_frame_idx=start_frame_idx,
#     725             # pass feature_cache for buffered backbone computation
#     726             feature_cache=feature_cache,
#     727         )
#     729 # note: detections in `sam3_image_out` has already gone through NMS
#     730 pred_probs = sam3_image_out["pred_logits"].squeeze(-1).sigmoid()
#
# File /cluster/scratch/niacobone/sam3/sam3/model/sam3_multiplex_detector.py:403, in Sam3MultiplexDetector.forward_video_grounding_multigpu(self, backbone_out, find_inputs, geometric_prompt, frame_idx, num_frames, multigpu_buffer, track_in_reverse, return_sam2_backbone_feats, run_nms, nms_prob_thresh, nms_iou_thresh, nms_use_iom, max_frame_num_to_track, propagate_in_video_start_frame_idx, feature_cache, **kwargs)
#     401 if frame_idx not in multigpu_buffer:
#     402     with torch.profiler.record_function("build_multigpu_buffer_next_chunk1"):
# --> 403         self._build_multigpu_buffer_next_chunk(
#     404             backbone_out=backbone_out,
#     405             find_inputs=find_inputs,
#     406             geometric_prompt=geometric_prompt,
#     407             frame_idx_begin=frame_idx_curr_b,
#     408             frame_idx_end=frame_idx_curr_e,
#     409             num_frames=num_frames,
#     410             multigpu_buffer=multigpu_buffer,
#     411             run_nms=run_nms,
#     412             nms_prob_thresh=nms_prob_thresh,
#     413             nms_iou_thresh=nms_iou_thresh,
#     414             nms_use_iom=nms_use_iom,
#     415             feature_cache=feature_cache,
#     416         )
#     418 # read out the current frame's results from `multigpu_buffer`
#     419 out = {}
#
# File /cluster/scratch/niacobone/sam3/sam3/model/sam3_multiplex_detector.py:501, in Sam3MultiplexDetector._build_multigpu_buffer_next_chunk(self, backbone_out, find_inputs, geometric_prompt, frame_idx_begin, frame_idx_end, num_frames, multigpu_buffer, run_nms, nms_prob_thresh, nms_iou_thresh, nms_use_iom, feature_cache)
#     499 # `forward_grounding` (from base class `Sam3MultiplexImageBase`) runs FA on a single frame
#     500 with torch.profiler.record_function("forward_grounding"):
# --> 501     out_local = self.forward_grounding(
#     502         backbone_out=backbone_out,
#     503         # HACK: Since find_inputs is on GPU having to realloc is expensive so changing the values in place for the prod usecase
#     504         # i.e. when using the streaming frame loader resource instead of local file. For non-prod is always
#     505         # frame_idx_local_gpu < len(find_inputs) so should be a no-op
#     506         find_input=find_inputs[frame_idx_local_gpu % len(find_inputs)],
#     507         find_target=None,
#     508         geometric_prompt=geometric_prompt,
#     509         feature_cache=feature_cache,
#     510     )
#     511 if run_nms:
#     512     with torch.profiler.record_function("nms_masks"):
#     513         # run NMS as a post-processing step on top of the detection outputs
#
# File /cluster/scratch/niacobone/sam3/sam3/model/sam3_image.py:449, in Sam3Image.forward_grounding(self, backbone_out, find_input, find_target, geometric_prompt, **kwargs)
#     440 def forward_grounding(
#     441     self,
#     442     backbone_out,
#    (...)    446     **kwargs,
#     447 ):
#     448     with torch.profiler.record_function("SAM3Image._encode_prompt"):
# --> 449         prompt, prompt_mask, backbone_out = self._encode_prompt(
#     450             backbone_out, find_input, geometric_prompt
#     451         )
#     452     # Run the encoder
#     453     with torch.profiler.record_function("SAM3Image._run_encoder"):
#
# File /cluster/scratch/niacobone/sam3/sam3/model/sam3_image.py:183, in Sam3Image._encode_prompt(self, backbone_out, find_input, geometric_prompt, visual_prompt_embed, visual_prompt_mask, encode_text, prev_mask_pred)
#     180 txt_feats = backbone_out["language_features"][:, txt_ids]
#     181 txt_masks = backbone_out["language_mask"][txt_ids]
# --> 183 feat_tuple = self._get_img_feats(backbone_out, find_input.img_ids)
#     184 backbone_out, img_feats, img_pos_embeds, vis_feat_sizes = feat_tuple
#     186 if prev_mask_pred is not None:
#
# File /cluster/scratch/niacobone/sam3/sam3/model/sam3_image.py:161, in Sam3Image._get_img_feats(self, backbone_out, img_ids)
#     155 id_mapping = torch.full(
#     156     (len(img_batch),), -1, dtype=torch.long, device=self.device
#     157 )
#     158 id_mapping[unique_ids] = torch.arange(len(unique_ids), device=self.device)
#     159 backbone_out = {
#     160     **backbone_out,
# --> 161     **self.backbone.forward_image(image),
#     162     "id_mapping": id_mapping,
#     163 }
#     164 assert "backbone_fpn" in backbone_out
#     165 return self._get_img_feats(backbone_out, img_ids=img_ids)
#
# File /cluster/scratch/niacobone/sam3/sam3/model/vl_combiner.py:200, in SAM3VLBackboneTri.forward_image(self, samples, need_sam3_out, need_interactive_out, need_propagation_out)
#     192 def forward_image(
#     193     self,
#     194     samples,
#    (...)    198     need_propagation_out: bool = True,
#     199 ):
# --> 200     return activation_ckpt_wrapper(self._forward_image_tri_no_act_ckpt)(
#     201         samples=samples,
#     202         need_sam3_out=need_sam3_out,
#     203         need_interactive_out=need_interactive_out,
#     204         need_propagation_out=need_propagation_out,
#     205         act_ckpt_enable=self.act_ckpt_whole_vision_backbone and self.training,
#     206     )
#
# File /cluster/scratch/niacobone/sam3/sam3/model/act_ckpt_utils.py:88, in activation_ckpt_wrapper.<locals>.act_ckpt_wrapper(act_ckpt_enable, use_reentrant, *args, **kwargs)
#      84     ret = checkpoint.checkpoint(
#      85         module, *args, use_reentrant=use_reentrant, **kwargs
#      86     )
#      87 else:
# ---> 88     ret = module(*args, **kwargs)
#      90 return ret
#
# File /cluster/scratch/niacobone/sam3/sam3/model/vl_combiner.py:222, in SAM3VLBackboneTri._forward_image_tri_no_act_ckpt(self, samples, need_sam3_out, need_interactive_out, need_propagation_out)
#     208 def _forward_image_tri_no_act_ckpt(
#     209     self,
#     210     samples,
#    (...)    213     need_propagation_out=True,
#     214 ):
#     215     (
#     216         sam3_features,
#     217         sam3_pos,
#     218         interactive_features,
#     219         interactive_pos,
#     220         propagation_features,
#     221         propagation_pos,
# --> 222     ) = self.vision_backbone.forward(
#     223         samples,
#     224         need_sam3_out=need_sam3_out,
#     225         need_interactive_out=need_interactive_out,
#     226         need_propagation_out=need_propagation_out,
#     227     )
#     228     if self.scalp > 0:
#     229         sam3_features, sam3_pos = (
#     230             sam3_features[: -self.scalp],
#     231             sam3_pos[: -self.scalp],
#     232         )
#
# File /cluster/scratch/niacobone/sam3/sam3/model/necks.py:218, in Sam3TriViTDetNeck.forward(self, tensor_list, need_sam3_out, need_interactive_out, need_propagation_out)
#     210 def forward(
#     211     self,
#     212     tensor_list,
#    (...)    216     need_propagation_out: bool = True,
#     217 ):
# --> 218     xs = self.trunk(tensor_list)
#     219     sam3_out = []
#     220     interactive_out = []
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File /cluster/scratch/niacobone/sam3/sam3/model/vitdet.py:985, in ViT.forward(self, tensor_list)
#     983     x = checkpoint.checkpoint(blk, x, use_reentrant=False)
#     984 else:
# --> 985     x = blk(x)
#     986 if (i == self.full_attn_ids[-1]) or (
#     987     self.return_interm_layers and i in self.full_attn_ids
#     988 ):
#     989     if i == self.full_attn_ids[-1]:
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File /cluster/scratch/niacobone/sam3/sam3/model/vitdet.py:732, in Block.forward(self, x)
#     729     H, W = x.shape[1], x.shape[2]
#     730     x, pad_hw = window_partition(x, self.window_size)
# --> 732 x = self.ls1(self.attn(x))
#     733 # Reverse window partition
#     734 if self.window_size > 0:
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File /cluster/scratch/niacobone/sam3/sam3/model/vitdet.py:613, in Attention.forward(self, x)
#     610 if self.use_fa3:
#     611     from sam3.perflib.fa3 import flash_attn_func
# --> 613     x = flash_attn_func(
#     614         q.transpose(1, 2), k.transpose(1, 2), v.transpose(1, 2)
#     615     ).transpose(1, 2)
#     616 else:
#     617     x = F.scaled_dot_product_attention(q, k, v)
#
# File /cluster/scratch/niacobone/sam3/sam3/perflib/fa3.py:19, in flash_attn_func(q, k, v)
#      17 def flash_attn_func(q, k, v):
#      18     dtype = torch.float8_e4m3fn
# ---> 19     return flash_attn_func_op(q.to(dtype), k.to(dtype), v.to(dtype)).to(q.dtype)
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/torch/_library/custom_ops.py:698, in CustomOpDef.__call__(self, *args, **kwargs)
#     697 def __call__(self, *args, **kwargs):
# --> 698     return self._opoverload(*args, **kwargs)
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/torch/_ops.py:819, in OpOverload.__call__(self, *args, **kwargs)
#     818 def __call__(self, /, *args: _P.args, **kwargs: _P.kwargs) -> _T:
# --> 819     return self._op(*args, **kwargs)
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/torch/_library/custom_ops.py:347, in CustomOpDef.register_kernel.<locals>.inner.<locals>.backend_impl(*args, **kwargs)
#     346 def backend_impl(*args, **kwargs):
# --> 347     result = self._backend_fns[device_type](*args, **kwargs)
#     349     def get_module():
#     350         fn = self._backend_fns[device_type]
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/torch/_compile.py:54, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      51     disable_fn = torch._dynamo.disable(fn, recursive, wrapping=False)
#      52     fn.__dynamo_disable = disable_fn  # type: ignore[attr-defined]
# ---> 54 return disable_fn(*args, **kwargs)
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:1181, in DisableContext.__call__.<locals>._fn(*args, **kwargs)
#    1171         with fx_traceback.annotate(
#    1172             {
#    1173                 "_torchdynamo_disable": True,
#    (...)   1178             }
#    1179         ):
#    1180             return fn(*args, **kwargs)
# -> 1181     return fn(*args, **kwargs)
#    1182 finally:
#    1183     set_eval_frame(None)
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/torch/_library/custom_ops.py:382, in CustomOpDef.register_kernel.<locals>.inner.<locals>.wrapped_fn(*args, **kwargs)
#     380     return self._init_fn(*args, **kwargs)
#     381 else:
# --> 382     return fn(*args, **kwargs)
#
# File /cluster/scratch/niacobone/sam3/sam3/perflib/fa3.py:14, in flash_attn_func_op(q, k, v)
#       8 @torch.library.custom_op("flash::flash_attn_func", mutates_args=())
#       9 def flash_attn_func_op(
#      10     q: torch.Tensor, k: torch.Tensor, v: torch.Tensor
#      11 ) -> torch.Tensor:
#      12     from flash_attn_interface import flash_attn_func as fa3
# ---> 14     return fa3(q, k, v)
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/flash_attn_interface.py:868, in flash_attn_func(q, k, v, softmax_scale, causal, qv, q_descale, k_descale, v_descale, window_size, attention_chunk, softcap, num_splits, pack_gqa, deterministic, sm_margin, return_attn_probs)
#     806 def flash_attn_func(
#     807     q,
#     808     k,
#    (...)    821     return_attn_probs=False,
#     822 ):
#     823     """dropout_p should be set to 0.0 during evaluation
#     824     Supports multi-query and grouped-query attention (MQA/GQA) by passing in KV with fewer heads
#     825     than Q. Note that the number of heads in Q must be divisible by the number of heads in KV.
#    (...)    866             normalization factor).
#     867     """
# --> 868     return FlashAttnFunc.apply(
#     869         q,
#     870         k,
#     871         v,
#     872         softmax_scale,
#     873         causal,
#     874         qv,
#     875         q_descale, k_descale, v_descale,
#     876         window_size,
#     877         attention_chunk,
#     878         softcap,
#     879         num_splits,
#     880         pack_gqa,
#     881         deterministic,
#     882         sm_margin,
#     883         return_attn_probs,
#     884     )
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/torch/autograd/function.py:583, in Function.apply(cls, *args, **kwargs)
#     580 if not torch._C._are_functorch_transforms_active():
#     581     # See NOTE: [functorch vjp and autograd interaction]
#     582     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 583     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     585 if not is_setup_ctx_defined:
#     586     raise RuntimeError(
#     587         "In order to use an autograd.Function with functorch transforms "
#     588         "(vmap, grad, jvp, jacrev, ...), it must override the setup_context "
#     589         "staticmethod. For more details, please see "
#     590         "https://pytorch.org/docs/main/notes/extending.func.html"
#     591     )
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/flash_attn_interface.py:573, in FlashAttnFunc.forward(ctx, q, k, v, softmax_scale, causal, qv, q_descale, k_descale, v_descale, window_size, attention_chunk, softcap, num_splits, pack_gqa, deterministic, sm_margin, return_softmax)
#     571     softmax_scale = (q.shape[-1] + (qv.shape[-1] if qv is not None else 0)) ** (-0.5)
#     572 # out, q, k, v, out_padded, softmax_lse = _flash_attn_forward(
# --> 573 out, softmax_lse, *rest = _flash_attn_forward(
#     574     q,
#     575     k,
#     576     v,
#     577     None, None,  # k_new, v_new
#     578     qv,  # qv
#     579     None,  # out
#     580     None, None, None,   # cu_seqlens_q/k/k_new
#     581     None, None,   # seqused_q/k
#     582     None, None,   # max_seqlen_q/k
#     583     None, None, None,   # page_table, kv_batch_idx, leftpad_k,
#     584     None, None, None,  # rotary_cos/sin, seqlens_rotary
#     585     q_descale, k_descale, v_descale,
#     586     softmax_scale,
#     587     causal=causal,
#     588     window_size_left=window_size[0],
#     589     window_size_right=window_size[1],
#     590     attention_chunk=attention_chunk,
#     591     softcap=softcap,
#     592     num_splits=num_splits,
#     593     pack_gqa=pack_gqa,
#     594     sm_margin=sm_margin,
#     595 )
#     596 # ctx.save_for_backward(q, k, v, out_padded, softmax_lse)
#     597 ctx.save_for_backward(q, k, v, out, softmax_lse)
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/torch/_library/custom_ops.py:698, in CustomOpDef.__call__(self, *args, **kwargs)
#     697 def __call__(self, *args, **kwargs):
# --> 698     return self._opoverload(*args, **kwargs)
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/torch/_ops.py:819, in OpOverload.__call__(self, *args, **kwargs)
#     818 def __call__(self, /, *args: _P.args, **kwargs: _P.kwargs) -> _T:
# --> 819     return self._op(*args, **kwargs)
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/torch/_library/custom_ops.py:347, in CustomOpDef.register_kernel.<locals>.inner.<locals>.backend_impl(*args, **kwargs)
#     346 def backend_impl(*args, **kwargs):
# --> 347     result = self._backend_fns[device_type](*args, **kwargs)
#     349     def get_module():
#     350         fn = self._backend_fns[device_type]
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/torch/_compile.py:54, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      51     disable_fn = torch._dynamo.disable(fn, recursive, wrapping=False)
#      52     fn.__dynamo_disable = disable_fn  # type: ignore[attr-defined]
# ---> 54 return disable_fn(*args, **kwargs)
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/torch/_dynamo/eval_frame.py:1181, in DisableContext.__call__.<locals>._fn(*args, **kwargs)
#    1171         with fx_traceback.annotate(
#    1172             {
#    1173                 "_torchdynamo_disable": True,
#    (...)   1178             }
#    1179         ):
#    1180             return fn(*args, **kwargs)
# -> 1181     return fn(*args, **kwargs)
#    1182 finally:
#    1183     set_eval_frame(None)
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/torch/_library/custom_ops.py:382, in CustomOpDef.register_kernel.<locals>.inner.<locals>.wrapped_fn(*args, **kwargs)
#     380     return self._init_fn(*args, **kwargs)
#     381 else:
# --> 382     return fn(*args, **kwargs)
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/flash_attn_interface.py:104, in _flash_attn_forward(q, k, v, k_new, v_new, qv, out_, cu_seqlens_q, cu_seqlens_k, cu_seqlens_k_new, seqused_q, seqused_k, max_seqlen_q, max_seqlen_k, page_table, kv_batch_idx, leftpad_k, rotary_cos, rotary_sin, seqlens_rotary, q_descale, k_descale, v_descale, softmax_scale, causal, window_size_left, window_size_right, attention_chunk, softcap, rotary_interleaved, scheduler_metadata, num_splits, pack_gqa, sm_margin)
#     102 rotary_cos, rotary_sin = [maybe_contiguous(x) for x in (rotary_cos, rotary_sin)]
#     103 seqlens_rotary = maybe_contiguous(seqlens_rotary)
# --> 104 out, softmax_lse, out_accum, softmax_lse_accum = flash_attn_3_gpu.fwd(
#     105     q,
#     106     k,
#     107     v,
#     108     k_new,
#     109     v_new,
#     110     qv,
#     111     out_,
#     112     cu_seqlens_q,
#     113     cu_seqlens_k,
#     114     cu_seqlens_k_new,
#     115     seqused_q,
#     116     seqused_k,
#     117     max_seqlen_q,
#     118     max_seqlen_k,
#     119     page_table,
#     120     kv_batch_idx,
#     121     leftpad_k,
#     122     rotary_cos,
#     123     rotary_sin,
#     124     seqlens_rotary,
#     125     q_descale,
#     126     k_descale,
#     127     v_descale,
#     128     softmax_scale,
#     129     causal,
#     130     window_size_left,
#     131     window_size_right,
#     132     attention_chunk,
#     133     softcap,
#     134     rotary_interleaved,
#     135     scheduler_metadata,
#     136     num_splits,
#     137     pack_gqa,
#     138     sm_margin,
#     139 )
#     141 if out_accum is None:
#     142     out_accum = torch.tensor([], device=out.device)
#
# File /cluster/scratch/niacobone/sam3/myenv/lib/python3.12/site-packages/torch/_ops.py:1209, in OpOverloadPacket.__call__(self, *args, **kwargs)
#    1206 if self._has_torchbind_op_overload and _must_dispatch_in_python(args, kwargs):
#    1207     # pyrefly: ignore [bad-argument-type]
#    1208     return _call_overload_packet_from_python(self, *args, **kwargs)
# -> 1209 return self._op(*args, **kwargs)
#
# RuntimeError: mha_fwd, /pytorch/third_party/flash-attention/hopper/flash_api_stable.cpp:787, FlashAttention on Ampere/Ada cards only supports fp16 and bf16 data type
# frame loading (image folder) [rank=0]:  66%|██████▋   | 179/270 [00:08<00:13,  6.80it/s]
# frame loading (image folder) [rank=0]: 100%|██████████| 270/270 [00:11<00:00, 24.44it/s]

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3.1 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ###  Removing objects
#
# We can remove individual objects using their id.
#
# As an example, let's remove object 2 (which is the dancer in the front).

# %%
# we pick id 2, which is the dancer in the front
obj_id = 2
response = predictor.handle_request(
    request=dict(
        type="remove_object",
        session_id=session_id,
        obj_id=obj_id,
    )
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3.1 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ### Adding new objects with point prompts
#
# We can add new objects through point prompts.
#
# Assuming that we've changed our mind, and now that we want to add back the dancer in the front (whom we just removed in the step above). We can use interactive clicks to add her back.

# %%
sample_img = Image.fromarray(load_frame(video_frames_for_vis[0]))

IMG_WIDTH, IMG_HEIGHT = sample_img.size

# %%
# let's add back the dancer via point prompts.
# we will use a single positive click to add the dancer back.

frame_idx = 0
obj_id = 2
points_abs = np.array(
    [
        [760, 550],  # positive click
    ]
)
# positive clicks have label 1, while negative clicks have label 0
labels = np.array([1])

# %%
# convert points and labels to tensors; also convert to relative coordinates
points_tensor = torch.tensor(
    abs_to_rel_coords(points_abs, IMG_WIDTH, IMG_HEIGHT, coord_type="point"),
    dtype=torch.float16,
)
points_labels_tensor = torch.tensor(labels, dtype=torch.int32)

response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        points=points_tensor,
        point_labels=points_labels_tensor,
        obj_id=obj_id,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3.1 Dense Tracking outputs"],
    figsize=(6, 4),
    points_list=[points_abs],
    points_labels_list=[labels],
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3.1 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ### Refining an existing object with point prompts
#
# We can also refine the segmentation mask of an existing object through point prompts.
#
# Assuming that we've changed our mind (again) -- for Object ID 2 (the dancer in the front whom we just added back in the step above), now we only want to segment her T-shirt instead of her whole body. We can adjust the segmentation mask with a few more positive and negative clicks.

# %%
# For the dancer in the front, suppose now we only want to segment her T-shirt instead of her whole body
# we will use 2 positive clicks and 2 negative clicks to select her shirt.

refine_object_3 = True

if refine_object_3:
    frame_idx = 0
    obj_id = 3
    points_abs = np.array(
        [
            [800, 135],  # positive click
            [800, 180],  # negative click
        ]
    )
    # positive clicks have label 1, while negative clicks have label 0
    labels = np.array([1, 0])
        
else:
    frame_idx = 0
    obj_id = 2
    points_abs = np.array(
        [
            [740, 450],  # positive click
            [760, 630],  # negative click
            [840, 640],  # negative click
            [760, 550],  # positive click
        ]
    )
    # positive clicks have label 1, while negative clicks have label 0
    labels = np.array([1, 0, 0, 1])

# %%
# convert points and labels to tensors; also convert to relative coordinates
points_tensor = torch.tensor(
    abs_to_rel_coords(points_abs, IMG_WIDTH, IMG_HEIGHT, coord_type="point"),
    dtype=torch.float16,
)
points_labels_tensor = torch.tensor(labels, dtype=torch.int32)

response = predictor.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        points=points_tensor,
        point_labels=points_labels_tensor,
        obj_id=obj_id,
    )
)
out = response["outputs"]

plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    video_frames_for_vis,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3.1 Dense Tracking outputs"],
    figsize=(6, 4),
    points_list=[points_abs],
    points_labels_list=[labels],
)

# %%
# now we propagate the outputs from frame 0 to the end of the video and collect all outputs
outputs_per_frame = propagate_in_video(predictor, session_id)

# finally, we reformat the outputs for visualization and plot the outputs every 60 frames
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)

vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx,
        video_frames_for_vis,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3.1 Dense Tracking outputs"],
        figsize=(6, 4),
    )

# %% [markdown]
# ### Close session
#
# Each session is tied to a single video. We can close the session after inference to free up its resources.
#
# (Then, you may start a new session on another video.)

# %%
_ = predictor.handle_request(
    request=dict(
        type="close_session",
        session_id=session_id,
    )
)
